# %% [markdown]
# # Task1_0527. 4개의 Series를 결합하여 데이터프레임을 생성하여 출력하세요.
# - 출력한 데이터프레임에서 추출하고 싶은 5개의 데이터를 인덱싱하여 출력
# - null값을 3개 추가
# - null값의 개수를 확인하고 삭제
# - 2개의 데이터를 수정
# - 1개의 행을 삭제

# %%
import numpy as np
import pandas as pd

# 시리즈 4개 생성
id = np.arange(1, 1001)
gender = np.random.randint(2, size=1000)
age = np.random.randint(1, 101, size=1000)
region = np.random.randint(1, 11, size=1000)
i1 = pd.Series(id)
g1 = pd.Series(gender)
a1 = pd.Series(age)
r1 = pd.Series(region)
# 데이터 프레임 생성
df = pd.concat([i1, g1, a1, r1], axis=1)
df.rename(columns={0: 'id', 1: 'gender', 2: 'age', 3: 'region'}, inplace=True)

# 데이터프레임에서 추출하고 싶은 5개의 데이터를 인덱싱하여 출력
print(df.iloc[[0, 1, 2, 3, 4]])

# null값을 3개 추가
df.loc[0, 'age'] = np.nan
df.loc[1, 'gender'] = np.nan
df.loc[2, 'region'] = np.nan

# null값의 개수를 확인하고 삭제
null_counts = df.isnull().sum()
print( null_counts,'\n')
df.dropna(inplace=True)
print(df.head(7))

# 2개의 데이터를 수정
df.loc[3, 'age'] = 50
df.loc[4, 'region'] = 5

# 1개의 행을 삭제
df.drop(index=5, inplace=True)

# 최종 데이터프레임 출력
print(df.head(7))
# Out:
#    id  gender  age  region
# 0   1       1   25      10
# 1   2       1   89       6
# 2   3       1   88      10
# 3   4       0   52       6
# 4   5       0   85       1
# id        0
# gender    1
# age       1
# region    1
# dtype: int64
#
#    id  gender   age  region
# 3   4     0.0  52.0     6.0
# 4   5     0.0  85.0     1.0
# 5   6     0.0  50.0     3.0
# 6   7     0.0  74.0     3.0
# 7   8     0.0   3.0     3.0
# 8   9     1.0  85.0     9.0
# 9  10     1.0   3.0     2.0
#     id  gender   age  region
# 3    4     0.0  50.0     6.0
# 4    5     0.0  85.0     5.0
# 6    7     0.0  74.0     3.0
# 7    8     0.0   3.0     3.0
# 8    9     1.0  85.0     9.0
# 9   10     1.0   3.0     2.0
# 10  11     0.0  42.0     5.0

# %% [markdown]
# ## ★ FOR SELF STUDY

# %% [markdown]
# ```
# import requests
# from bs4 import BeautifulSoup
#
# # 크롤링할 웹 페이지 URL
# url = 'https://sports.daum.net/record/mlb/batter'
#
# # 웹 페이지 요청
# response = requests.get(url)
#
# # 요청이 성공했는지 확인
# if response.status_code == 200:
#     html = response.text
#
#     # Beautiful Soup 객체 생성
#     soup = BeautifulSoup(html, 'html.parser')
#
#     # 선수, 타율, 홈런, 도루 데이터를 담을 리스트
#     players_data = []
#
#     # 선수 데이터가 있는 테이블 행들을 찾습니다.
#     # 테이블 구조에 따라 변경될 수 있습니다.
#     table_rows = soup.select('table.tbl_record tr') # 예제이므로 실제 구조에 따라 변경 필요
#
#     # 각 행에서 데이터를 추출합니다.
#     for row in table_rows[1:]:  # 첫 번째 행은 헤더이므로 제외
#         cols = row.find_all('td')
#         if len(cols) > 0:
#             player = cols[1].text.strip()  # 선수 이름 (예시로 2번째 열)
#             avg = cols[3].text.strip()     # 타율 (예시로 4번째 열)
#             hr = cols[5].text.strip()      # 홈런 (예시로 6번째 열)
#             sb = cols[9].text.strip()      # 도루 (예시로 10번째 열)
#             players_data.append({
#                 'player': player,
#                 'avg': avg,
#                 'hr': hr,
#                 'sb': sb
#             })
#
#     # 추출한 데이터 출력
#     for player_data in players_data:
#         print(player_data)
# else:
#     print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# ```

# %%
class Mlb :
  def __init__(self) :
    self.mlb_24 = {
      'Shohei Ohtani':[0.336, 13, 13],
      'Luis Arraez':[0.335, 1, 3],
      'Mookie Betts':[0.335, 8, 9],
      'William Contreras':[0.332, 8, 3],
      'Jurickson Profar':[0.319, 7, 3]
    }
# '선수' : [타율, 홈런, 도루] 의 형태로 data를 입력받기.
  def input_player(self, player) :
    input_stats = []
    if player not in self.mlb_24 :
      try :
        bat_avg = float(input("타율 : "))
        homerun = int(input("홈런개수 : "))
        stolen_bs = int(input("도루개수 : "))

        self.mlb_24[player] = [bat_avg, homerun, stolen_bs]

      except ValueError :
        print("형식에 맞게 입력.")
mlb = Mlb()
mlb.input_player('Lee Do Heon')
import pandas as pd

mlb_24 = pd.DataFrame(mlb.mlb_24)
mlb_24 = mlb_24.transpose()
mlb_24.columns = ['타율', '홈런', '도루']
mlb_24.index.name = '선수명'

print(f"{'*'*15} MLB.com {'*'*15}\n\n{mlb_24}")
print('\n ▼▼ NaN 값 추가 ▼▼\n')
mlb_24.loc['Lee Do Heon'] = None
mlb_24.loc['Kim Ha Seong'] = None
print(f"{'*'*15} MLB.com {'*'*15}\n\n{mlb_24}")
print("Unexpected Detected : \n", mlb_24.isnull().sum())
mlb_24.drop(['Lee Do Heon'], axis=0, inplace=True)
print("Drop unexpected player : COMPLETE")
mlb_24.loc['Kim Ha Seong'] = [ 0.216, 6, 13 ]
print("Input missing stats : COMPLETE")
print(f"{'*'*15} MLB.com {'*'*15}\n\n{mlb_24}")
mlb_24 = pd.DataFrame({
    'Shohei Ohtani':[0.336, 13, 13],
    'Luis Arraez':[0.335, 1, 3],
    'Mookie Betts':[0.335, 8, 9],
    'William Contreras':[0.332, 8, 3],
    'Kim Ha Seong':[0.216, 6, 13],
    'Lee Do Heon':[0.412, 40, 40]
})
# 선수명이 인덱스가 되도록 해주기 위해 transpose() 메서드를 이용해 인덱스와 컬럼을 바꿔주기.
mlb_24 = mlb_24.transpose()
# 0, 1, 2 로 되어있는 변경된 컬럼에 이름 지어주기.
mlb_24.columns = ['타율', '홈런', '도루']
# 인덱스에 '선수명'이라는 이름 넣어주기
mlb_24.index.name = '선수명'
print(f"{'*'*15} MLB.com {'*'*15}\n\n{mlb_24}")

# %% [markdown]
# # Task2_0527. 학생별 성적 데이터셋으로 의미있게 데이터 셋을 수정하세요.(아래 사항 반영)
# - S1 ~ S10은 평균 점수를 기준으로 1등급에서 10등급이고 등급간 점수 차는 5점
# - 결시자가 국어 3명, 수학 2명 있음
# - 영어, 수학의 평균 점수가 국어 대비 5점 낮음

# %%
import pandas as pd
import numpy as np

df = np.random.seed(0)
df = np.random.randint(1,5,size=(10,5))
df=pd.DataFrame(df,index=['s1','s2','s3','s4','s5','s6','s7','s8','s9','s10'],
               columns=['국어','영어','수학','과학','사회'])
df
# Out:
#      국어  영어  수학  과학  사회
# s1    1   4   2   1   4
# s2    4   4   4   2   4
# s3    2   3   1   4   3
# s4    1   1   1   3   2
# s5    3   4   4   3   1
# s6    2   2   2   2   1
# s7    2   1   4   1   4
# s8    2   3   4   4   1
# s9    3   4   1   2   4
# s10   2   4   4   3   4

# %%
# 등급 간 점수 차는 5점
for i in range(10) :
  df.iloc[i] = 90 - i*5
df
# Out:
#      국어  영어  수학  과학  사회
# s1   90  90  90  90  90
# s2   85  85  85  85  85
# s3   80  80  80  80  80
# s4   75  75  75  75  75
# s5   70  70  70  70  70
# s6   65  65  65  65  65
# s7   60  60  60  60  60
# s8   55  55  55  55  55
# s9   50  50  50  50  50
# s10  45  45  45  45  45

# %%
# 영어, 수학의 평균 점수가 국어 대비 5점 낮음
for i in range(10) :
  df.iloc[i, 1:3] = df.iloc[i, 0] - 5
df
# Out:
#      국어  영어  수학  과학  사회
# s1   90  85  85  90  90
# s2   85  80  80  85  85
# s3   80  75  75  80  80
# s4   75  70  70  75  75
# s5   70  65  65  70  70
# s6   65  60  60  65  65
# s7   60  55  55  60  60
# s8   55  50  50  55  55
# s9   50  45  45  50  50
# s10  45  40  40  45  45

# %%
# 결시자가 국어 3명, 수학 2명 있음
a = df.copy()
a.iloc[7:, 0] = np.nan
a.iloc[8:, 2] = np.nan
a
# Out:
#        국어  영어    수학  과학  사회
# s1   90.0  85  85.0  90  90
# s2   85.0  80  80.0  85  85
# s3   80.0  75  75.0  80  80
# s4   75.0  70  70.0  75  75
# s5   70.0  65  65.0  70  70
# s6   65.0  60  60.0  65  65
# s7   60.0  55  55.0  60  60
# s8    NaN  50  50.0  55  55
# s9    NaN  45   NaN  50  50
# s10   NaN  40   NaN  45  45

# %% [markdown]
# # Task3_0527. df1에서 결측값 처리 후 딕셔너리, 리스트로 변환하여 출력하세요.

# %%
df1 = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Math": [85, np.nan, 88, 90, 76],
    "English": [92, 85, 89, np.nan, 80],
    "Science": [78, 90, 95, 85, 89],
    "History": [88, 92, 85, 91, np.nan]
})
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Math     4 non-null      float64
#  2   English  4 non-null      float64
#  3   Science  5 non-null      int64
#  4   History  4 non-null      float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 328.0+ bytes

# %%
# 숫자 열에 대한 결측값을 각 열의 평균값으로 대체
df2 = df1.copy()
columns = ['Math', 'English', 'Science', 'History']
for column in columns :
  df2[column].fillna(df2[column].mean(), inplace=True)
df2
# Out:
#       Name  Math  English  Science  History
# 0    Alice  85.0     92.0       78     88.0
# 1      Bob   NaN     85.0       90     92.0
# 2  Charlie  88.0     89.0       95     85.0
# 3    David  90.0      NaN       85     91.0
# 4      Eve  76.0     80.0       89      NaN

# %%
# 배열로 변환
arr1 = df2.to_numpy()
print(arr1)

# 딕셔너리로 변환
dict1 = df2.to_dict(orient='list')
print(dict1)

# 리스트로 변환
lst1 = df2.values.tolist()
print(lst1)
# Out:
# [['Alice' 85.0 92.0 78 88.0]
#  ['Bob' nan 85.0 90 92.0]
#  ['Charlie' 88.0 89.0 95 85.0]
#  ['David' 90.0 nan 85 91.0]
#  ['Eve' 76.0 80.0 89 nan]]
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'], 'Math': [85.0, nan, 88.0, 90.0, 76.0], 'English': [92.0, 85.0, 89.0, nan, 80.0], 'Science': [78, 90, 95, 85, 89], 'History': [88.0, 92.0, 85.0, 91.0, nan]}
# [['Alice', 85.0, 92.0, 78, 88.0], ['Bob', nan, 85.0, 90, 92.0], ['Charlie', 88.0, 89.0, 95, 85.0], ['David', 90.0, nan, 85, 91.0], ['Eve', 76.0, 80.0, 89, nan]]

# %%
# df 1 데이터 프레임에서 숫자형 데이터 타입을 가진 열들만 선택
df2 = df1.copy()
for column in df2.select_dtypes(include=[np.number]).columns :
  df1[column].fillna(df2[column].mean(), inplace=True)

#결과 출력
df2

# %% [markdown]
# # Task4_0527. df2에서 아래와 같이 데이터 필터링 및 정렬 후 배열, 딕셔너리, 리스트로 변환하여 출력하세요.
# - Math 점수가 80 이상인 학생만 선택
# - English 점수를 기준으로 내림차순 정렬

# %%
df2 = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Math": [85, 79, 88, 90, 76],
    "English": [92, 85, 89, 93, 80],
    "Science": [78, 90, 95, 85, 89],
    "History": [88, 92, 85, 91, 84]
})
# Math 점수가 80 이상인 학생만 선택
filtered_df = df2[df2['Math'] >= 80]

# English 점수를 기준으로 내림차순 정렬
sorted_df = filtered_df.sort_values(by='English', ascending=False)

# 배열로 변환
array_result = sorted_df.values
# 딕셔너리로 변환
dict_result = sorted_df.to_dict(orient='list')
# 리스트로 변환
list_result = sorted_df.to_dict(orient='records')

# 결과 출력
print("Array Result:\n", array_result)
print("\nDictionary Result:\n", dict_result)
print("\nList Result:\n", list_result)
# Out:
# Array Result:
#  [['David' 90 93 85 91]
#  ['Alice' 85 92 78 88]
#  ['Charlie' 88 89 95 85]]
#
# Dictionary Result:
#  {'Name': ['David', 'Alice', 'Charlie'], 'Math': [90, 85, 88], 'English': [93, 92, 89], 'Science': [85, 78, 95], 'History': [91, 88, 85]}
#
# List Result:
#  [{'Name': 'David', 'Math': 90, 'English': 93, 'Science': 85, 'History': 91}, {'Name': 'Alice', 'Math': 85, 'English': 92, 'Science': 78, 'History': 88}, {'Name': 'Charlie', 'Math': 88, 'English': 89, 'Science': 95, 'History': 85}]

# %% [markdown]
# # Task5_0527. df3에서 각 학생의 평균 점수 계산 후 배열, 딕셔너리, 리스트로 변환하여 출력하세요.

# %%
df3 = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice", "Bob", "Charlie", "David", "Eve"],
    "Subject": ["Math", "Math", "Math", "Math", "Math", "English", "English", "English", "English", "English"],
    "Score": [85, 79, 88, 90, 76, 92, 85, 89, 93, 80]
})
df3
# Out:
#       Name  Subject  Score
# 0    Alice     Math     85
# 1      Bob     Math     79
# 2  Charlie     Math     88
# 3    David     Math     90
# 4      Eve     Math     76
# 5    Alice  English     92
# 6      Bob  English     85
# 7  Charlie  English     89
# 8    David  English     93
# 9      Eve  English     80

# %%
df3.pivot_table(index='Name', columns='Subject', values='Score', aggfunc='mean')
# Out:
# Subject  English  Math
# Name
# Alice         92    85
# Bob           85    79
# Charlie       89    88
# David         93    90
# Eve           80    76

# %%
df3_pivot = df3.pivot_table(index='Name', columns='Subject', values='Score', aggfunc='mean').reset_index()
df3_pivot.columns.name = None
df3_pivot
# Out:
#       Name  English  Math
# 0    Alice       92    85
# 1      Bob       85    79
# 2  Charlie       89    88
# 3    David       93    90
# 4      Eve       80    76

# %%
# 배열로 변환
arr3 = df3_pivot.to_numpy()
print(arr3, '\n')

# 딕셔너리로 변환
dict3 = df3_pivot.to_dict(orient='list')
print(dict3, '\n')

# 리스트로 변환
lst3 = df3_pivot.values.tolist()
print(lst3, '\n')

# %% [markdown]
# # Task6_0527. df4에서 특정 열의 데이터 타입을 변환한 후 변환된 타입을 확인하세요.

# %%
df4 = pd.DataFrame({
    'A': ['1', '2', '3', '4'],
    'B': ['5.1', '6.2', '7.3', '8.4'],
    'C': ['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01']
})
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      object
#  1   B       4 non-null      object
#  2   C       4 non-null      object
# dtypes: object(3)
# memory usage: 224.0+ bytes

# %%
# 'A' 열을 정수형(int)으로 변환
df4['A'] = df4['A'].astype(int)

# 'B' 열을 부동 소수점(float)으로 변환
df4['B'] = df4['B'].astype(float)

# 'C' 열을 datetime 형식으로 변환
df4['C'] = pd.to_datetime(df4['C'])

# 데이터 타입 확인
print(df4.dtypes)
# Out:
# A             int64
# B           float64
# C    datetime64[ns]
# dtype: object

# %% [markdown]
# # Task7_0527. df5에서 나이가 25 이상인 행을 출력하세요.

# %%
df5 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
})
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
# 조건에 따라 데이터프레임의 부분집합 선택 (나이가 25 이상인 행)
subset = df5[df5['Age'] >= 25]
print("\n나이가 25 이상인 행 : \n\n", subset)
# Out:
# 나이가 25 이상인 행 :
#
#      Name  Age         City
# 1    Bob   27  Los Angeles
# 3  David   32      Houston
# 4    Eve   29      Phoenix
